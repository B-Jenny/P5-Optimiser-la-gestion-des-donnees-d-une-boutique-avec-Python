# %% [markdown]
# <div>
#     <div style="display: flex; text-align:center; background-color: RGB( 254, 249, 231 );border: 1px solid RGB(51,165,182);" id="partie0">
#         <h1 style="margin: auto; padding: 30px;margin-left: 2em; text-indent: -2em">
#             Projet 5 -Optimisez la gestion des données d'une boutique avec Python
#         </h1>
#     </div>
# </div>

# %% [markdown]
# <div>
#     <div style="border-style: double;border-width: 5px;border-color: RGB(51,165,182);" >
#         <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182);margin-left: 4.5em; text-indent: -4.5em">Ce programme est organisé en plusieurs partie :
#         </h3>
#         <div style="margin: auto;padding-left: 40px;padding-bottom: 20px;margin-left: 4.5em; text-indent: -4.5em">
#             <lu>
#                 <li><a href="#contexte">Contexte du projet 5</a></li>
#                 <li><a href="#partie1">Partie 1</a> : Librairies et fonctions</li>
#                 <li><a href="#partie2">Partie 2</a> : Importer les fichiers et initialiser les Dataframe</li>
#                 <li><a href="#partie3">Partie 3</a> : La mission : réponses aux questions</li>
#                 <li><a href="#Conclusion">Conclusion</a></li>
#                 <li><a href="#Références">Références</a></li>
#            </lu>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div>
#     <div style="background-color: RGB(51,165,182);" id="contexte">
#         <h2 style="margin: auto; padding: 20px; color:#fff;margin-left: 4.5em; text-indent: -4.5em">
#             Contexte du projet 5
#         </h2>
#         <font size="-0"><a href="#contexte">  🔝  </a></font>
#     </div>
# </div>

# %% [markdown]
# ## Laurent le manager m'a donné pour mission dans un premier temps la réunion de deux dataFrames, afin d'avoir sur un même dataFrame les informations sur les produits, notamment sur le nom, la description, le nombre de ventes....
#
# ## Dans un second temps unir au nouveau dataFrame contenant les informations des produits commercialisés en ligne, Sylvie l'ancienne stagiaire, a créée un tableau Excel où les id concernant la boutique et la boutique en ligne, on pu être associé.
#
# ## L'objectif du traitement de données est le calcul du chiffre d'affaire par produit puis le calcul du total du chiffre d'affaire
#
#
#
#
#
# ![image_bottleneck.png](attachment:image_bottleneck.png)

# %% [markdown]
# <div>
#     <div style="background-color: RGB(51,165,182);" id="partie1">
#         <h2 style="margin: auto; padding: 20px; color:#fff;margin-left: 4.5em; text-indent: -4.5em">
#             Partie 1 - Librairies et fonctions
#         </h2>
#         <font size="-0"><a href="#partie0">  🔝  </a></font>
#     </div>
# </div>

# %% [markdown]
# <div>
#     <div style="border: 1px solid RGB(51,165,182);" >
#         <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182);margin-left: 4.5em; text-indent: -4.5em">
#             1.1 - Importation les librairies
#         </h3>
#         <font size="-0"><a href="#partie0">  🔝  </a></font>
#     </div>
# </div>

# %%
# Importation des librairies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Permet de pouvoir visualiser toute les lignes
pd.set_option("max_rows", None)

# %% [markdown]
# <div>
#     <div style="border: 1px solid RGB(51,165,182);" >
#         <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182);margin-left: 4.5em; text-indent: -4.5em">
#             1.2 - Déclaration des fonctions
#         </h3>
#         <font size="-0"><a href="#partie0">  🔝  </a></font>
#     </div>
# </div>

# %%
# déclaration d'une fonction
def analyseDataFrame(df):
    """Fonction qui prend en arguments un dataframe pour analyse."""

    name =[x for x in globals() if globals()[x] is df][0]
    print("La dimension de DataFrame « " + name  +" » : " + str(df.shape) + " (lignes, colonnes)\n")
    display(temp_var = df.info())
    display(df.describe().T)
    display(df.head(5))
    
    # Afficher les colonnes qui sont unique dans le DataFrame df
    print("Test d'unicité sur les colonnes de DataFrame :")
    test_unicite = 0
    for col in df.columns :
        if df[col].size == df.drop_duplicates(col)[col].size :
          display(f'« {col:s} » est unique, et pourrait être une clé primaire.')
          test_unicite = 1
    if test_unicite == 0 :
        print("Il n'y a pas d'unicité dans aucune colonne. Il n'y a pas de clé primaire")

    print("Compter les nulles pour chaque colonne :")
    display(df.isnull().sum())

# %% [markdown]
# <div>
#     <div style="background-color: RGB(51,165,182);" id="partie2">
#         <h2 style="margin: auto; padding: 20px; color:#fff;margin-left: 4.5em; text-indent: -4.5em">
#             Partie 2 - Importer les fichiers et initialiser les Dataframe
#         </h2>
#         <font size="-0"><a href="#partie0">  🔝  </a></font>
#     </div>
# </div>

# %% [markdown]
# <div>
#     <div style="border: 1px solid RGB(51,165,182);" >
#         <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182); ">
#             2.1 - Importation et traitement des données
#         </h3>
#         <div style="margin: auto;padding-left: 40px;padding-bottom: 20px;">
#             <lu>
#                 <li> erp
#                 <li> liaison
#                 <li> web
#             </lu>
#         </div>
#         <font size="-0"><a href="#partie0">  🔝  </a></font>
#     </div>
#     </div>

# %%
# N'affichera plus le message de warning concernant excel
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

# Importation des données au format excel
df_erp = pd.read_excel('erp.xlsx')
df_liaison = pd.read_excel('liaison.xlsx')
df_web = pd.read_excel('web.xlsx')

# %% [markdown]
# ### Données 'erp'

# %%
# visualisation de erp
analyseDataFrame(df_erp)
# Out:
# La dimension de DataFrame « df_erp » : (825, 5) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 32.4+ KB
#                 count         mean         std     min     25%     50%  \
# product_id      825.0  5162.597576  902.644635  3847.0  4348.0  4907.0
# onsale_web      825.0     0.869091    0.337506     0.0     1.0     1.0
# price           825.0    32.415636   26.795849     5.2    14.6    24.4
# stock_quantity  825.0    26.496970   45.892422     0.0     1.0    11.0
#
#                    75%     max
# ...

# %%
# Vérification des duplicatas pour la colonne 'product_id'
df_erp.product_id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Données 'liaison'

# %%
# Visualisation de liaison
analyseDataFrame(df_liaison)
# Out:
# La dimension de DataFrame « df_liaison » : (825, 2) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  825 non-null    int64
#  1   id_web      734 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 13.0+ KB
#             count         mean         std     min     25%     50%     75%  \
# product_id  825.0  5162.597576  902.644635  3847.0  4348.0  4907.0  5805.0
#
#                max
# product_id  7338.0
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815
# Test d'unicité sur les colonnes de DataFrame :
# '« product_id » est unique, et pourrait être une clé primaire.'
# Compter les nulles pour chaque colonne :
# product_id     0
# id_web        91
# dtype: int64

# %%
# Visualisation des données nulles de la colonne 'id_web'
df_liaison[df_liaison.id_web.isnull()]
# Out:
#      product_id id_web
# 19         4055    NaN
# 49         4090    NaN
# 50         4092    NaN
# 119        4195    NaN
# 131        4209    NaN
# 151        4233    NaN
# 184        4278    NaN
# 185        4279    NaN
# 234        4565    NaN
# 238        4577    NaN
# 239        4578    NaN
# 242        4594    NaN
# 246        4599    NaN
# 292        4659    NaN
# 318        4692    NaN
# 319        4693    NaN
# 320        4697    NaN
# 321        4698    NaN
# 322        4702    NaN
# 340        4721    NaN
# 352        4738    NaN
# 356        4744    NaN
# 384        4798    NaN
# 396        4874    NaN
# 416        4911    NaN
# 449        4973    NaN
# 469        5017    NaN
# 472        5020    NaN
# 486        5070    NaN
# 487        5075    NaN
# 541        5560    NaN
# 547        5569    NaN
# 618        5805    NaN
# 621        5808    NaN
# 659        5952    NaN
# 696        6125    NaN
# 724        6324    NaN
# 726        6327    NaN
# 739        6594    NaN
# ...

# %%
# Visualisation des duplicatas
df_liaison.duplicated().sum()
# Out:
# 0

# %%
# Création d'un jeu de données sans les valeurs nulles de la colonne 'id_web'
df_liaison_notnull = df_liaison[df_liaison.id_web.notnull()]
analyseDataFrame(df_liaison_notnull)
# Out:
# La dimension de DataFrame « df_liaison_notnull » : (734, 2) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  734 non-null    int64
#  1   id_web      734 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 17.2+ KB
#             count         mean         std     min      25%     50%      75%  \
# product_id  734.0  5041.859673  790.309295  3847.0  4287.25  4862.5  5714.25
#
#                max
# product_id  7338.0
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815
# Test d'unicité sur les colonnes de DataFrame :
# '« product_id » est unique, et pourrait être une clé primaire.'
# '« id_web » est unique, et pourrait être une clé primaire.'
# Compter les nulles pour chaque colonne :
# product_id    0
# ...

# %% [markdown]
# ### Données 'web'

# %%
# Visualisation de web
analyseDataFrame(df_web)
# Out:
# La dimension de DataFrame « df_web » : (1513, 28) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1428 non-null   object
#  1   virtual                1513 non-null   int64
#  2   downloadable           1513 non-null   int64
#  3   rating_count           1513 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   datetime64[ns]
#  10  post_date_gmt          1430 non-null   datetime64[ns]
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
# ...

# %%
# Visualisation des données nulles de la colonne 'sku'
df_web[df_web.sku.isnull()]
# Out:
#      sku  virtual  downloadable  rating_count  average_rating  total_sales  \
# 178  NaN        0             0             0             NaN          NaN
# 179  NaN        0             0             0             NaN          NaN
# 227  NaN        0             0             0             NaN          NaN
# 230  NaN        0             0             0             NaN          NaN
# 231  NaN        0             0             0             NaN          NaN
# 233  NaN        0             0             0             NaN          NaN
# 237  NaN        0             0             0             NaN          NaN
# 283  NaN        0             0             0             NaN          NaN
# 309  NaN        0             0             0             NaN          NaN
# 310  NaN        0             0             0             NaN          NaN
# 311  NaN        0             0             0             NaN          NaN
# ...

# %%
# les lignes 470 et 471 semblent présenter une erreur à vérifier avec l'équipe
df_web[df_web.sku.isnull() & df_web.post_name.notnull()]
# Out:
#      sku  virtual  downloadable  rating_count  average_rating  total_sales  \
# 470  NaN        0             0             0             0.0          0.0
# 471  NaN        0             0             0             0.0          0.0
#
#     tax_status  tax_class  post_author           post_date  ...  \
# 470    taxable        NaN          2.0 2018-07-31 12:07:23  ...
# 471    taxable        NaN          2.0 2018-08-08 11:23:43  ...
#
#                                       post_name       post_modified  \
# 470  pierre-jean-villa-cote-rotie-fongeant-2017 2019-11-02 13:24:15
# 471    pierre-jean-villa-condrieu-suspendu-2018 2019-11-02 13:24:01
#
#       post_modified_gmt post_content_filtered post_parent  \
# 470 2019-11-02 12:24:15                   NaN         0.0
# 471 2019-11-02 12:24:01                   NaN         0.0
#
#                                                   guid menu_order  post_type  \
# 470  https://www.bottle-neck.fr/?post_type=product&...        0.0    product
# ...

# %%
# Visualisation des duplicatas
df_web.sku.duplicated().sum()
# Out:
# 798

# %%
# Suppression des données dupliquées de la colonne 'sku'
df_web = df_web.drop_duplicates(subset = ['sku'])

# %%
# Création d'un jeu de données sans les valeurs nulles de la colonne 'sku'
df_web_notnull = df_web[df_web.sku.notnull()]
analyseDataFrame(df_web_notnull)

# Création d'un dataFrame contenant uniquement les valeurs 'product' de la colonne 'post_type'
df_produits = df_web_notnull[df_web_notnull['post_type']=='product']
analyseDataFrame(df_produits)
# Out:
# La dimension de DataFrame « df_web_notnull » : (714, 28) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 798
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    714 non-null    object
#  1   virtual                714 non-null    int64
#  2   downloadable           714 non-null    int64
#  3   rating_count           714 non-null    int64
#  4   average_rating         714 non-null    float64
#  5   total_sales            714 non-null    float64
#  6   tax_status             714 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            714 non-null    float64
#  9   post_date              714 non-null    datetime64[ns]
#  10  post_date_gmt          714 non-null    datetime64[ns]
#  11  post_content           0 non-null      float64
# ...

# %%
# Création d'une  jointure externe afin de permettre l'union des colonnes et le remplissage des valeurs nulles 
df_erp_liaison = pd.merge(df_erp, df_liaison_notnull,
                      on = 'product_id', how = 'outer', indicator = True)

# Visualisation du jeu de données erp_liaison
analyseDataFrame(df_erp_liaison)

# Visualisation du nombre de données unique de la colonne _merge
display(df_erp_liaison['_merge'].nunique())
# Out:
# La dimension de DataFrame « df_erp_liaison » : (825, 7) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825 entries, 0 to 824
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
#  5   id_web          734 non-null    object
#  6   _merge          825 non-null    category
# dtypes: category(1), float64(1), int64(3), object(2)
# memory usage: 46.1+ KB
#                 count         mean         std     min     25%     50%  \
# product_id      825.0  5162.597576  902.644635  3847.0  4348.0  4907.0
# onsale_web      825.0     0.869091    0.337506     0.0     1.0     1.0
# price           825.0    32.415636   26.795849     5.2    14.6    24.4
# ...

# %% [markdown]
# #### La colonne '_merge' contient qu'une données unique : 'both'

# %%
# Supression de la colonne '_merge'
df_erp_liaison = df_erp_liaison.drop(['_merge'], axis = 1)

# %%
# Création de la seconde jointure externe cette fois-ci avec des entrées de contenue à droite et à gauche
df_final = pd.merge(df_produits, df_erp_liaison, 
                      left_on = 'sku', right_on = 'id_web',  how = 'outer', indicator = True)


# Visualisation du jeu de données erp_lia_web
analyseDataFrame(df_final)

# Visualisation du nombre de données unique de la colonne _merge
display(df_final['_merge'].unique())
# Out:
# La dimension de DataFrame « df_final » : (825, 35) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825 entries, 0 to 824
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    714 non-null    object
#  1   virtual                714 non-null    float64
#  2   downloadable           714 non-null    float64
#  3   rating_count           714 non-null    float64
#  4   average_rating         714 non-null    float64
#  5   total_sales            714 non-null    float64
#  6   tax_status             714 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            714 non-null    float64
#  9   post_date              714 non-null    datetime64[ns]
#  10  post_date_gmt          714 non-null    datetime64[ns]
#  11  post_content           0 non-null      float64
# ...

# %%
# création d'un jeu données avec uniquement les produits de données web
df_final_right = df_final[df_final['_merge'] == 'right_only']

# Visualisation du jeu de données erp_lia_web_right
analyseDataFrame(df_final_right)
# Out:
# La dimension de DataFrame « df_final_right » : (111, 35) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111 entries, 714 to 824
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    0 non-null      object
#  1   virtual                0 non-null      float64
#  2   downloadable           0 non-null      float64
#  3   rating_count           0 non-null      float64
#  4   average_rating         0 non-null      float64
#  5   total_sales            0 non-null      float64
#  6   tax_status             0 non-null      object
#  7   tax_class              0 non-null      float64
#  8   post_author            0 non-null      float64
#  9   post_date              0 non-null      datetime64[ns]
#  10  post_date_gmt          0 non-null      datetime64[ns]
#  11  post_content           0 non-null      float64
# ...

# %%
# Observation des lignes dont l'id_web n'est pas nul
df_id_web_notnull = df_final_right[df_final_right['id_web'].notnull()]

analyseDataFrame(df_id_web_notnull)
# Out:
# La dimension de DataFrame « df_id_web_notnull » : (20, 35) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 805 to 824
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    0 non-null      object
#  1   virtual                0 non-null      float64
#  2   downloadable           0 non-null      float64
#  3   rating_count           0 non-null      float64
#  4   average_rating         0 non-null      float64
#  5   total_sales            0 non-null      float64
#  6   tax_status             0 non-null      object
#  7   tax_class              0 non-null      float64
#  8   post_author            0 non-null      float64
#  9   post_date              0 non-null      datetime64[ns]
#  10  post_date_gmt          0 non-null      datetime64[ns]
#  11  post_content           0 non-null      float64
# ...

# %%
# Supression de données 
df_final.drop(df_final[df_final['_merge'] != 'both'].index, inplace = True)

# Choix des colonnes
df_final = df_final[['sku', 'total_sales', 'product_id', 'id_web', 'price', 'post_title']]

# Visualisation de toutes les données de 'erp_lia_web'
analyseDataFrame(df_final)
# Out:
# La dimension de DataFrame « df_final » : (714, 6) (lignes, colonnes)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 713
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          714 non-null    object
#  1   total_sales  714 non-null    float64
#  2   product_id   714 non-null    int64
#  3   id_web       714 non-null    object
#  4   price        714 non-null    float64
#  5   post_title   714 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 39.0+ KB
#              count         mean         std     min      25%      50%  \
# total_sales  714.0     4.012605    8.518183     0.0     0.00     1.00
# product_id   714.0  5032.557423  790.510878  3847.0  4280.25  4796.00
# price        714.0    32.493137   27.810525     5.2    14.10    23.55
#
#                   75%     max
# total_sales     4.000    96.0
# product_id   5710.500  7338.0
# ...

# %% [markdown]
# <div>
#     <div style="background-color: RGB(51,165,182);" id="partie3">
#         <h2 style="margin: auto; padding: 20px; color:#fff;margin-left: 4.5em; text-indent: -4.5em">
#             Partie 3 - La mission : réponses aux questions
#         </h2>
#         <font size="-0"><a href="#partie0">  🔝  </a></font>
#     </div>
# </div>

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">CA par produit et total</h3>
# </div>

# %%
# Création d'un jeu données avec une nouvelle colonne ayant pour valeur le total des ventes par produit
vente_par_produit = df_final.assign(ca_produit = (df_final.total_sales) * (df_final.price))
vente_par_produit
# Out:
#                      sku  total_sales  product_id               id_web  \
# 0    bon-cadeau-25-euros         10.0        4954  bon-cadeau-25-euros
# 1                  15298          6.0        3847                15298
# 2                  15296          0.0        3849                15296
# 3                  15300          0.0        3850                15300
# 4                  19814          3.0        4032                19814
# 5                  19815          0.0        4039                19815
# 6                  15303          0.0        4040                15303
# 7                  14975          0.0        4041                14975
# 8                  16042          7.0        4042                16042
# 9                  14980          3.0        4043                14980
# 10                 16041         14.0        4045                16041
# 11                 15269          6.0        4046                15269
# ...

# %%
# Calcul du chiffre d'affaire
total_ca = vente_par_produit['ca_produit'].sum()
print('Le total CA est de',total_ca)
# Out:
# Le total CA est de 70568.6

# %% [markdown]
# # TOTAL DE CA  = 70 568,60

# %%
# Contrôl des doublon pour 'sku'
df_final[df_final.duplicated(['post_title'])].sort_values('post_title')
# Out:
#          sku  total_sales  product_id   id_web  price  \
# 712  13127-1          0.0        7247  13127-1   54.8
# 698    16068          1.0        6665    16068   27.7
# 490    14828          0.0        5544    14828   61.6
#
#                                             post_title
# 712       Clos du Mont-Olivet Châteauneuf-du-Pape 2007
# 698           Domaine Hauvette IGP Alpilles Jaspe 2017
# 490  Marc Colin Et Fils Chassagne-Montrachet Blanc ...

# %% [markdown]
# ###### La colonne post_title semble présenter 3 doublons

# %%
# Vérification doublon 1
df_doub_1 = df_final[(df_final.post_title == 'Clos du Mont-Olivet Châteauneuf-du-Pape 2007')]
df_doub_1
# Out:
#          sku  total_sales  product_id   id_web  price  \
# 469    16034          3.0        5465    16034   54.8
# 712  13127-1          0.0        7247  13127-1   54.8
#
#                                        post_title
# 469  Clos du Mont-Olivet Châteauneuf-du-Pape 2007
# 712  Clos du Mont-Olivet Châteauneuf-du-Pape 2007

# %%
# Vérification doublon 2
df_doub_2 = df_final[(df_final.post_title == 'Domaine Hauvette IGP Alpilles Jaspe 2017')]
df_doub_2
# Out:
#        sku  total_sales  product_id id_web  price  \
# 185  15292          1.0        4288  15292   26.7
# 698  16068          1.0        6665  16068   27.7
#
#                                    post_title
# 185  Domaine Hauvette IGP Alpilles Jaspe 2017
# 698  Domaine Hauvette IGP Alpilles Jaspe 2017

# %%
# Affichage de la ligne 581 pour la colonne post_title
df_final.post_title.iloc[581]
# Out:
# 'Maison Trimbach Riesling Cuvée Frédéric Emile 2012'

# %%
# Vérification doublon 3
df_doub_3 = df_final[(df_final.post_title == 'Marc Colin Et Fils Chassagne-Montrachet Blanc Les Vide-Bourses 1er Cru 2016')]
df_doub_3
# Out:
#        sku  total_sales  product_id id_web  price  \
# 230  14000          2.0        4597  14000   61.6
# 490  14828          0.0        5544  14828   61.6
#
#                                             post_title
# 230  Marc Colin Et Fils Chassagne-Montrachet Blanc ...
# 490  Marc Colin Et Fils Chassagne-Montrachet Blanc ...

# %%
# choix des colonnes pour le listing des vins
df_listing_vins = df_final[['total_sales', 'price', 'post_title']]

# %%
# Calcul du chiffre d'affaire du listing des vins
df_listing_vins = df_listing_vins.assign(ca_vins = (df_listing_vins.total_sales) * (df_listing_vins.price))
df_listing_vins
# Out:
#      total_sales   price                                         post_title  \
# 0           10.0   25.00                                  Bon cadeau de 25€
# 1            6.0   24.20        Pierre Jean Villa Saint-Joseph Préface 2018
# 2            0.0   34.30    Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# 3            0.0   20.80  Pierre Jean Villa Crozes-Hermitage Accroche Co...
# 4            3.0   14.10  Pierre Jean Villa IGP Collines Rhodaniennes Ga...
# 5            0.0   46.00          Pierre Jean Villa Côte Rôtie Carmina 2017
# 6            0.0   34.30  Pierre Jean Villa Saint-Joseph Saut De l'Ange ...
# 7            0.0   32.70                      Pierre Gaillard Condrieu 2018
# 8            7.0   31.20                        Pierre Gaillard Cornas 2017
# 9            3.0   60.00   Pierre Gaillard Côte Rôtie Esprit de Blonde 2017
# 10          14.0   42.60                    Pierre Gaillard Côte Rôtie 2018
# ...

# %%
# prix du vin le moins cher
prix_mini = df_listing_vins[df_listing_vins.price == df_listing_vins.price.min()]
prix_mini
# Out:
#      total_sales  price                                         post_title  \
# 645          0.0    5.2  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...
#
#      ca_vins
# 645      0.0

# %%
print('le vin le moins cher est le', df_listing_vins.post_title.iloc[645])
# Out:
# le vin le moins cher est le Moulin de Gassac IGP Pays d'Hérault Guilhem Blanc 2017

# %%
# prix du vin le plus cher
prix_max = df_listing_vins[df_listing_vins.price == df_listing_vins.price.max()]
prix_max
# Out:
#      total_sales  price                                      post_title  \
# 200          5.0  225.0  Champagne Egly-Ouriet Grand Cru Millésimé 2008
#
#      ca_vins
# 200   1125.0

# %%
print('le vin le plus cher est le', df_listing_vins.post_title.iloc[200])
# Out:
# le vin le plus cher est le Champagne Egly-Ouriet Grand Cru Millésimé 2008

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">Analyse univariée : Méthode des interquartiles</h3>
# </div>

# %%
# Calcul interquartile
Q1= df_listing_vins['price'].quantile(q=0.25)
Q3= df_listing_vins['price'].quantile(q=0.75)  
IQR= Q3 - Q1 

# Calcul des valeurs extrêmes
Lower = (Q1 - 1.5*IQR) 
Upper = (Q3 + 1.5*IQR)

# Outlier
outlier = df_listing_vins[(df_listing_vins['price'] > Upper) | (df_listing_vins['price'] < Lower)].sort_values('price')

# Visualisation
print('Q1                          :', Q1)
print('Q3                          :', Q3)
print('Borne minimum               :', Lower)
print('Borne maximum               :', Upper)
print('Etendue interquartile (IQR) :', IQR)
print("Nombre d'outliers           : " + str(len(outlier)))

# Visualisation des outliers
outlier
# Out:
# Q1                          : 14.1
# Q3                          : 42.175000000000004
# Borne minimum               : -28.012500000000003
# Borne maximum               : 84.28750000000001
# Etendue interquartile (IQR) : 28.075000000000003
# Nombre d'outliers           : 32
#      total_sales  price                                         post_title  \
# 206          1.0   85.6  Champagne Larmandier-Bernier Grand Cru Les Che...
# 438          0.0   86.8  Champagne Agrapart &amp; Fils Minéral Extra Br...
# 66           0.0   88.4  Zind-Humbrecht Pinot Gris Grand Cru Rangen De ...
# 502          0.0   92.0                      Tempier Bandol Cabassaou 2017
# 602          0.0   93.0  Wemyss Malts Single Cask Scotch Whisky Chocola...
# 655          0.0   99.0  Domaine des Comtes Lafon Volnay 1er Cru Champa...
# 64           0.0  100.0  Zind-Humbrecht Riesling Grand Cru Rangen De Th...
# 381          0.0  102.3  Domaine Des Croix Corton Grand Cru Les Grèves ...
# ...

# %%
sns.boxplot(x=outlier['price'], palette='pastel', )
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# Diagramme des prix en nuage des points (Les outliers en ROUGE)
df_produits_OK = df_listing_vins[(df_listing_vins['price'] < Upper) & (df_listing_vins['price'] > Lower)]
df_produits_outliers = df_listing_vins[(df_listing_vins['price'] > Upper) | (df_listing_vins['price'] < Lower)]

# On plot en rouge les produits outliers
plt.scatter(df_produits_OK['price'].index, df_produits_OK['price'].values)
plt.scatter(df_produits_outliers['price'].index, df_produits_outliers['price'].values,c='red')
plt.show()

# %% [markdown]
# # Conclusion
# <br /><br /><font size="-0"><a href="#partie0">  🔝  </a></font>

# %% [markdown]
# ##  Après nettoyage et analyse des données traitées, BottleNeck indique avoir réalisé un CA  de 70568,60.
#
# ## Les données traitées on présentés plusieurs valeurs nulles ainsi que plusieurs duplicatas particulièrement sur le DataFrame 'df_web'.
#
# ## J'ai constater également sur l'un des doublons que le prix de l'article mentionné était de deux valeurs différentes j'attend de voir avec l'équipe.
#
# ## Les prix indiquent  32 outliers, detectés par la méthode d'interquartiles, ces prix semblent correspondre à des vins plus préstigieux, comme par exemple du cognac ou encore du champagne, ces données se trouvent en dehors de la boite à moustache, les données ne sont pas forcément faussées mais peut être sont seulement différentes.

# %% [markdown]
# # Références
# - [Openclassrooms : Initiez-vous à Python pour l'analyse de données](https://openclassrooms.com/fr/courses/6204541-initiez-vous-a-python-pour-lanalyse-de-donnees)
# - [Openclassrooms : Nettoyez et analysez votre jeu de données](https://openclassrooms.com/fr/courses/7410486-nettoyez-et-analysez-votre-jeu-de-donnees)
# - [Openclassrooms : Découvrez les librairies Python pour la Data Science](https://openclassrooms.com/fr/courses/4452741-decouvrez-les-librairies-python-pour-la-data-science)
#
# <br /><font size="-0"><a href="#partie0">🔝  </a></font>
